# %% [markdown]
# Databricks Notebooks

# %%
# %sql
select 'a'

# %%
print("Hello World")

# %% [markdown]
# Data Objects
# - Catalog
# - Schema
# - Tables, View, Volume

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)

# %%
# %sql
use catalog acc_dev;
create schema ashok

# %%
# %sql
use catalog acc_dev;
use schema ashok;

# %%
# %sql
create table acc_dev.ashok.newtable(id int primary key)
