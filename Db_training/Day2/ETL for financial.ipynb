# %%
from pyspark.sql.functions import *

# %%
df=spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv", header=True, inferSchema=True)
df.display()

# %%
df1=df.withColumnsRenamed({"TransactionID":"Trans_id","CustomerID":"Cust_id","AccountType":"Acc_type","TransactionType":"Trans_type","TransactionDate":"Trans_date"})
df1.display()

# %%
df.withColumn("ingestion_date",current_timestamp()).display()
