-- %%
%sql
use catalog acc_dev;
use schema ashok;

-- %%
create table if not exists emp(id int, name string, city string)

-- %%
insert into emp values (1,'Ashok','Hyd')

-- %%
select * from emp

-- %%
desc detail emp

-- %%
desc extended emp

-- %%
desc history emp

-- %%
insert into emp values (3,'Krishna','Hyd'),(4,'krish','Pune')

-- %%
delete from emp where id=1

-- %%
select * from emp version as of 2

-- %%
insert into acc_dev.naval.emp values ('13','Ashok','Hyd')

-- %%
delete from emp

-- %%
select * from emp

-- %%
desc history emp

-- %%
restore table emp to version as of 2
