# %%
# %run "/Workspace/Users/g.ashokkumar413@gmail.com/Db_training/Day3/multi hop/includes"

# %%
# reader
df=spark.table(f"{catalog}.{schema}.sales")

#transform
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.ashok_silver.sales_cleaned")
