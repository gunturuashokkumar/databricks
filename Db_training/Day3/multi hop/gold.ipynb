# %%
# %sql
create or replace view acc_dev.ashok_gold.top_customers as
(select customer_id, round(sum(total_amount)) as total_amount from acc_dev.ashok_silver.sales_cleaned group by customer_id order by total_amount desc limit 3)
